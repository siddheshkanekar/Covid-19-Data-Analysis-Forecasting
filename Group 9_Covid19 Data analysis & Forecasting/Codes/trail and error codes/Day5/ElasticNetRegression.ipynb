# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures
import pandas as pd
import numpy as np
import os
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import KFold,cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
os.chdir('C:/Users/dbda/Desktop/ML/Datasets')

# %%
boston = pd.read_csv('Boston.csv')
x = boston.drop('medv', axis = 1)
y = boston['medv']

# %%
from sklearn.linear_model import ElasticNet

# %%
elastic=ElasticNet()

# %% [markdown]
# ### Grid Search

# %%
params = {'alpha': np.linspace(0.001, 5,20),
         'l1_ratio':np.linspace(0.001, 1,10)}
kfold = KFold(n_splits = 5, shuffle = True, random_state = 23)

# %%
gcv = GridSearchCV(elastic, cv = kfold, param_grid = params)
gcv.fit(x,y)
# Out:
# GridSearchCV(cv=KFold(n_splits=5, random_state=23, shuffle=True),
#              estimator=ElasticNet(),
#              param_grid={'alpha': array([1.00000000e-03, 2.64105263e-01, 5.27210526e-01, 7.90315789e-01,
#        1.05342105e+00, 1.31652632e+00, 1.57963158e+00, 1.84273684e+00,
#        2.10584211e+00, 2.36894737e+00, 2.63205263e+00, 2.89515789e+00,
#        3.15826316e+00, 3.42136842e+00, 3.68447368e+00, 3.94757895e+00,
#        4.21068421e+00, 4.47378947e+00, 4.73689474e+00, 5.00000000e+00]),
#                          'l1_ratio': array([0.001, 0.112, 0.223, 0.334, 0.445, 0.556, 0.667, 0.778, 0.889,
#        1.   ])})

# %%
pd.DataFrame(gcv.cv_results_)
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time param_alpha  \
# 0         0.001402      0.001748         0.000615        0.000806       0.001
# 1         0.000000      0.000000         0.003130        0.006260       0.001
# 2         0.000000      0.000000         0.003123        0.006246       0.001
# 3         0.003124      0.006249         0.000000        0.000000       0.001
# 4         0.003124      0.006247         0.000000        0.000000       0.001
# ..             ...           ...              ...             ...         ...
# 195       0.003124      0.006249         0.000000        0.000000         5.0
# 196       0.003124      0.006248         0.000000        0.000000         5.0
# 197       0.000000      0.000000         0.000000        0.000000         5.0
# 198       0.003125      0.006250         0.000000        0.000000         5.0
# 199       0.003124      0.006248         0.000000        0.000000         5.0
#
#     param_l1_ratio                               params  split0_test_score  \
# 0            0.001  {'alpha': 0.001, 'l1_ratio': 0.001}           0.747827
# 1            0.112  {'alpha': 0.001, 'l1_ratio': 0.112}           0.747712
# 2            0.223  {'alpha': 0.001, 'l1_ratio': 0.223}           0.747572
# 3            0.334  {'alpha': 0.001, 'l1_ratio': 0.334}           0.747404
# 4            0.445  {'alpha': 0.001, 'l1_ratio': 0.445}           0.747203
# ..             ...                                  ...                ...
# 195          0.556    {'alpha': 5.0, 'l1_ratio': 0.556}           0.549190
# 196          0.667    {'alpha': 5.0, 'l1_ratio': 0.667}           0.537077
# 197          0.778    {'alpha': 5.0, 'l1_ratio': 0.778}           0.526567
# 198          0.889    {'alpha': 5.0, 'l1_ratio': 0.889}           0.524912
# 199            1.0      {'alpha': 5.0, 'l1_ratio': 1.0}           0.523138
#
#      split1_test_score  split2_test_score  split3_test_score  \
# 0             0.689302           0.735261           0.680888
# 1             0.689679           0.735122           0.681150
# 2             0.690071           0.734962           0.681420
# 3             0.690479           0.734780           0.681698
# 4             0.690904           0.734572           0.681986
# ..                 ...                ...                ...
# 195           0.594671           0.588131           0.577593
# 196           0.583418           0.575654           0.568650
# 197           0.568319           0.563548           0.557871
# 198           0.565346           0.561383           0.552081
# 199           0.564000           0.559106           0.549997
#
#      split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0             0.738284         0.718313        0.027566               10
# 1             0.738283         0.718389        0.027374                9
# 2             0.738270         0.718459        0.027167                8
# 3             0.738244         0.718521        0.026944                7
# 4             0.738202         0.718573        0.026702                6
# ..                 ...              ...             ...              ...
# 195           0.567276         0.575372        0.016070              179
# 196           0.559779         0.564915        0.015956              187
# 197           0.549878         0.553237        0.014682              195
# 198           0.550992         0.550943        0.014109              199
# 199           0.552021         0.549652        0.014170              200
#
# [200 rows x 15 columns]

# %%
print('GCV best score: ', gcv.best_score_)
print('GCV best parameters: ', gcv.best_params_)
# Out:
# GCV best score:  0.7186437476922446
# GCV best parameters:  {'alpha': 0.001, 'l1_ratio': 0.778}
