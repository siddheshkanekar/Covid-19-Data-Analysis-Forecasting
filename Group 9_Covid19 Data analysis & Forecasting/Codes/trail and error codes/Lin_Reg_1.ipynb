# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import numpy as np

# %%
housing = pd.read_csv("C:/Training/Academy/Statistics (Python)/Datasets/Housing.csv")
housing.dtypes
# Out:
# price       float64
# lotsize       int64
# bedrooms      int64
# bathrms       int64
# stories       int64
# driveway     object
# recroom      object
# fullbase     object
# gashw        object
# airco        object
# garagepl      int64
# prefarea     object
# dtype: object

# %%
plt.scatter(housing['lotsize'], housing['price'])
plt.xlabel("Area")
plt.ylabel("Price")
plt.show()

# %%
housing['lotsize'].corr(housing['price'])
# Out:
# 0.5357956724321838

# %%
X = housing[['lotsize']]
y = housing['price']
lr = LinearRegression()
lr.fit(X, y)
print(lr.intercept_, lr.coef_)
# Out:
# 34136.19156491505 [6.59876759]

# %%
ycap = 34136.19156491505 + housing['lotsize']*6.59876759

# %%
np.sum((y - ycap)**2)
# Out:
# 277043862881.15326

# %%
X = housing[['lotsize','bedrooms','bathrms']]
y = housing['price']
lr = LinearRegression()
lr.fit(X, y)
print(lr.intercept_, lr.coef_)
# Out:
# -2418.292616740757 [5.41120044e+00 5.82680241e+03 1.97502101e+04]

# %%
ycap = -2418.292616740757 + housing['lotsize']*5.41120044 + housing['bedrooms']*5.82680241e+03 + 1.97502101e+04*housing['bathrms']

# %%
np.sum((y - ycap)**2)
# Out:
# 199628303501.08502

# %%
plt.scatter(ycap, y)
plt.xlabel("Estimated y")
plt.ylabel("Actual y")
plt.show()

# %%
housing
# Out:
#         price  lotsize  bedrooms  bathrms  stories driveway recroom fullbase  \
# 0     42000.0     5850         3        1        2      yes      no      yes
# 1     38500.0     4000         2        1        1      yes      no       no
# 2     49500.0     3060         3        1        1      yes      no       no
# 3     60500.0     6650         3        1        2      yes     yes       no
# 4     61000.0     6360         2        1        1      yes      no       no
# ..        ...      ...       ...      ...      ...      ...     ...      ...
# 541   91500.0     4800         3        2        4      yes     yes       no
# 542   94000.0     6000         3        2        4      yes      no       no
# 543  103000.0     6000         3        2        4      yes     yes       no
# 544  105000.0     6000         3        2        2      yes     yes       no
# 545  105000.0     6000         3        1        2      yes      no       no
#
#     gashw airco  garagepl prefarea
# 0      no    no         1       no
# 1      no    no         0       no
# 2      no    no         0       no
# 3      no    no         0       no
# 4      no    no         0       no
# ..    ...   ...       ...      ...
# 541    no   yes         0       no
# 542    no   yes         0       no
# 543    no   yes         1       no
# 544    no   yes         1       no
# 545    no   yes         1       no
#
# [546 rows x 12 columns]

# %%
housing['driveway'] = np.where(housing['driveway'] == "yes", 1, 0)
housing
# Out:
#         price  lotsize  bedrooms  bathrms  stories  driveway recroom fullbase  \
# 0     42000.0     5850         3        1        2         1      no      yes
# 1     38500.0     4000         2        1        1         1      no       no
# 2     49500.0     3060         3        1        1         1      no       no
# 3     60500.0     6650         3        1        2         1     yes       no
# 4     61000.0     6360         2        1        1         1      no       no
# ..        ...      ...       ...      ...      ...       ...     ...      ...
# 541   91500.0     4800         3        2        4         1     yes       no
# 542   94000.0     6000         3        2        4         1      no       no
# 543  103000.0     6000         3        2        4         1     yes       no
# 544  105000.0     6000         3        2        2         1     yes       no
# 545  105000.0     6000         3        1        2         1      no       no
#
#     gashw airco  garagepl prefarea
# 0      no    no         1       no
# 1      no    no         0       no
# 2      no    no         0       no
# 3      no    no         0       no
# 4      no    no         0       no
# ..    ...   ...       ...      ...
# 541    no   yes         0       no
# 542    no   yes         0       no
# 543    no   yes         1       no
# 544    no   yes         1       no
# 545    no   yes         1       no
#
# [546 rows x 12 columns]

# %%
X = housing[['lotsize','bedrooms','bathrms','driveway']]
y = housing['price']
lr = LinearRegression()
lr.fit(X, y)
print(lr.intercept_, lr.coef_)
# Out:
# -11501.414051187356 [4.78495477e+00 6.19654687e+03 1.96887926e+04 1.31448062e+04]

# %%
ycap = -11501.414051187356 + housing['lotsize']*4.78495477 + housing['bedrooms']*6.19654687e+03 + 1.96887926e+04*housing['bathrms'] + 1.31448062e+04*housing['driveway']

# %% [markdown]
# OR

# %%
ycap = lr.predict(X)

# %%
np.sum((y - ycap)**2)
# Out:
# 189190016788.43976

# %% [markdown]
# Reloading the same data

# %%
housing = pd.read_csv("C:/Training/Academy/Statistics (Python)/Datasets/Housing.csv")
housing.dtypes
# Out:
# price       float64
# lotsize       int64
# bedrooms      int64
# bathrms       int64
# stories       int64
# driveway     object
# recroom      object
# fullbase     object
# gashw        object
# airco        object
# garagepl      int64
# prefarea     object
# dtype: object

# %% [markdown]
# ### One Hot Encoding / Dummying

# %%
dum_hous = pd.get_dummies(housing, drop_first=True)
X = dum_hous.drop('price', axis=1)
y = dum_hous['price']

# %%
lr = LinearRegression()
lr.fit(X, y)
print(lr.intercept_, lr.coef_)
# Out:
# -4038.3504250983533 [3.54630297e+00 1.83200347e+03 1.43355585e+04 6.55694571e+03
#  4.24482900e+03 6.68777889e+03 4.51128383e+03 5.45238554e+03
#  1.28314063e+04 1.26328904e+04 9.36951324e+03]

# %%
ycap = lr.predict(X)
np.sum((y - ycap)**2)
# Out:
# 127025071644.46799

# %% [markdown]
# ## Salaries Dataset

# %%
sals = pd.read_csv("C:/Training/Academy/Statistics (Python)/Datasets/Salaries.csv")

# %%
dum_sals = pd.get_dummies(sals, drop_first=True)

# %%
X = dum_sals.drop('salary', axis=1)
y = dum_sals['salary']
lr = LinearRegression()
lr.fit(X, y)
ycap = lr.predict(X)

# %%
pd.DataFrame(zip(X.columns, lr.coef_))
# Out:
#                0             1
# 0  yrs.since.phd    535.058282
# 1    yrs.service   -489.515715
# 2  rank_AsstProf -12907.587900
# 3      rank_Prof  32158.410772
# 4   discipline_B  14417.625571
# 5       sex_Male   4783.492837

# %%
lr.intercept_
# Out:
# 78862.82025652143

# %%
per1 = np.array([20,10,1,0,1,0])
per2 = np.array([21,10,1,0,1,0])

# %%
sal_1 = lr.intercept_ + np.dot(per1 , lr.coef_)
sal_1
# Out:
# 86178.86641433643

# %%
sal_2 = lr.intercept_ + np.dot(per2 , lr.coef_)
sal_2
# Out:
# 86713.92469629477

# %%
sal_2 - sal_1
# Out:
# 535.058281958336

# %%
per1 = np.array([10,20,0,0,1,1])
per2 = np.array([10,20,0,0,0,1])

# %%
sal_1 = lr.intercept_ + np.dot(per1 , lr.coef_)
sal_1
# Out:
# 93624.20717912869

# %%
sal_2 = lr.intercept_ + np.dot(per2 , lr.coef_)
sal_2
# Out:
# 79206.58160858166

# %%
sal_2 - sal_1
# Out:
# -14417.625570547025

# %% [markdown]
# Mean Squared Error

# %%
np.mean((y-ycap)**2)
# Out:
# 499033585.7054836

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y, ycap)
# Out:
# 499033585.7054836

# %% [markdown]
# ### Small Dataset

# %%
x = np.array([34, 56, 87, 109, 120])
y = np.array([340, 550, 879, 1090, 1230])
plt.scatter(x, y)
plt.show()

# %%
lr.fit(x.reshape(-1, 1), y)
# Out:
# LinearRegression()

# %%
lr.intercept_, lr.coef_
# Out:
# (-17.238154131560464, array([10.28372111]))

# %%
ycap = -17.238154131560464 + 10.28372111*x
ycap
# Out:
# array([ 332.40836361,  558.65022803,  877.44558244, 1103.68744686,
#        1216.80837907])

# %%
y
# Out:
# array([ 340,  550,  879, 1090, 1230])

# %%
np.sum((y - ycap)**2)
# Out:
# 496.2406663059479
